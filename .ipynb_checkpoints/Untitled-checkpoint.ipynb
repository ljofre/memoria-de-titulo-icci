# %%
from seismic_source import SeismicEvent, Source

e = SeismicEvent.evento("./data-sets/1998_aug_02_07_30_40.d5g")
# Out:
# importado!

# %%
#Retorna un objeto con los resultados
Source.source(e)
# Out:
# (array([[  1.84055047e+03,   1.56006662e+08,   3.71802342e+10,
#           -2.41956633e+10],
#         [  1.84055098e+03,  -3.78107002e+09,  -5.51746134e+10,
#            4.44699483e+10],
#         [  1.84055148e+03,   2.67841964e+09,   3.53117939e+09,
#           -3.34304490e+08],
#         [  1.84055199e+03,  -8.60052390e+09,   8.66868107e+10,
#           -6.72450325e+10],
#         [  1.84055249e+03,  -2.06441905e+10,   1.76501891e+10,
#           -1.78483989e+10],
#         [  1.84055300e+03,  -6.38294466e+10,  -1.16579125e+10,
#           -5.96676450e+09],
#         [  1.84055350e+03,   3.87843057e+10,   2.68070840e+10,
#           -6.19818161e+09],
#         [  1.84055401e+03,   9.90168440e+10,  -3.77253551e+10,
#            5.73897390e+10],
#         [  1.84055451e+03,  -8.04150226e+10,   1.71532404e+10,
#           -3.25540618e+10],
#         [  1.84055502e+03,  -5.20374822e+09,   3.26319628e+10,
#           -2.19767542e+10],
# ...
